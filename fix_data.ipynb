# %%
import pandas as pd

# %%
df = pd.read_csv('data/train_pax.csv')
df['departure_date'] = pd.to_datetime(df['departure_date'], format='%Y-%m-%d')
df['departure_time'] = pd.to_datetime(df['departure_time'], format='%Y-%m-%d %H:%M:%S').dt.time

# %%
df.dtypes
# Out:
# train_number                                int64
# departure_date                     datetime64[ns]
# departure_time                             object
# boarding_station_name                      object
# boarding_station_name_latitude            float64
# boarding_station_name_longitude           float64
# arrival_station_name                       object
# arrival_station_name_latitude             float64
# arrival_station_name_longitude            float64
# pax_EU_count                                int64
# pax_non_EU_count                            int64
# adult_pax_count                             int64
# senior_pax_count                            int64
# youth_pax_count                             int64
# infant_pax_count                            int64
# pax_veg_meal_count                          int64
# pax_non_veg_meal_count                      int64
# pax_diabetic_meal_count                     int64
# pax_vegan_meal_count                        int64
# assistance_required_count                   int64
# dtype: object

# %%
df
# Out:
#     train_number departure_date departure_time boarding_station_name  \
# 0           9010     2024-12-25       05:15:00     London St Pancras
# 1           9020     2024-12-25       06:30:00     London St Pancras
# 2           9030     2024-12-25       07:05:00     London St Pancras
# 3           9040     2024-12-25       08:20:00          Gare du Nord
# 4           9050     2024-12-25       09:05:00          Gare du Nord
# 5           9060     2024-12-25       10:37:00     London St Pancras
# 6           9070     2024-12-25       11:24:00     London St Pancras
# 7           9080     2024-12-25       12:33:00     London St Pancras
# 8           9090     2024-12-25       13:01:00     London St Pancras
# 9           9100     2024-12-25       14:08:00          Gare du Nord
# 10          9110     2024-12-25       15:23:00          Gare du Nord
# 11          9120     2024-12-25       16:04:00     London St Pancras
# 12          9130     2024-12-25       17:05:00     London St Pancras
# 13          9140     2024-12-25       18:10:00          Gare du Nord
# 14          9150     2024-12-25       19:01:00     London St Pancras
# 15          9160     2024-12-25       20:30:00     London St Pancras
# 16          9170     2024-12-25       21:40:00     London St Pancras
# 17          9180     2024-12-25       22:00:00     London St Pancras
#
#     boarding_station_name_latitude  boarding_station_name_longitude  \
# 0                          51.5304                          -0.1260
# 1                          51.5304                          -0.1260
# 2                          51.5304                          -0.1260
# 3                          48.8794                           2.3557
# 4                          48.8794                           2.3557
# 5                          51.5304                          -0.1260
# 6                          51.5304                          -0.1260
# 7                          51.5304                          -0.1260
# 8                          51.5304                          -0.1260
# 9                          48.8794                           2.3557
# 10                         48.8794                           2.3557
# 11                         51.5304                          -0.1260
# 12                         51.5304                          -0.1260
# 13                         48.8794                           2.3557
# 14                         51.5304                          -0.1260
# 15                         51.5304                          -0.1260
# 16                         51.5304                          -0.1260
# 17                         51.5304                          -0.1260
#
#    arrival_station_name  arrival_station_name_latitude  \
# 0          Gare du Nord                        48.8794
# 1          Gare du Nord                        48.8794
# 2          Gare du Nord                        48.8794
# 3     London St Pancras                        51.5304
# 4     London St Pancras                        51.5304
# 5          Gare du Nord                        48.8794
# 6          Gare du Nord                        48.8794
# 7          Gare du Nord                        48.8794
# 8          Gare du Nord                        48.8794
# 9     London St Pancras                        51.5304
# 10    London St Pancras                        51.5304
# 11         Gare du Nord                        48.8794
# 12         Gare du Nord                        48.8794
# 13    London St Pancras                        51.5304
# 14         Gare du Nord                        48.8794
# 15         Gare du Nord                        48.8794
# 16         Gare du Nord                        48.8794
# 17         Gare du Nord                        48.8794
#
#     arrival_station_name_longitude  pax_EU_count  pax_non_EU_count  \
# 0                           2.3557           150                50
# 1                           2.3557           160                40
# 2                           2.3557           155                45
# 3                          -0.1260           170                30
# 4                          -0.1260           180                40
# 5                           2.3557           190                45
# 6                           2.3557           185                40
# 7                           2.3557           160                50
# 8                           2.3557           175                35
# 9                          -0.1260           165                40
# 10                         -0.1260           155                45
# 11                          2.3557           145                50
# 12                          2.3557           150                60
# 13                         -0.1260           160                55
# 14                          2.3557           170                50
# 15                          2.3557           180                45
# 16                          2.3557           185                40
# 17                          2.3557           190                35
#
#     adult_pax_count  senior_pax_count  youth_pax_count  infant_pax_count  \
# 0               100                30               20                 5
# 1               110                25               18                 7
# 2               105                28               22                 6
# 3               120                35               15                10
# 4               125                30               18                12
# 5               130                33               25                12
# 6               120                29               22                 7
# 7               110                26               20                 8
# 8               115                27               24                 6
# 9               110                30               19                 6
# 10              105                29               23                 7
# 11               95                31               20                 9
# 12              100                28               22                10
# 13              110                33               24                 8
# 14              120                30               22                10
# 15              130                35               18                12
# 16              135                32               20                 9
# 17              140                32               21                 9
#
#     pax_veg_meal_count  pax_non_veg_meal_count  pax_diabetic_meal_count  \
# 0                   20                      80                       10
# 1                   25                      85                       12
# 2                   22                      78                        8
# 3                   30                      90                       15
# 4                   28                      92                       13
# 5                   35                      95                       14
# 6                   32                      88                       12
# 7                   24                      82                       10
# 8                   30                      85                       11
# 9                   28                      80                        9
# 10                  20                      75                       12
# 11                  18                      72                       10
# 12                  22                      77                       18
# 13                  25                      82                       16
# 14                  28                      85                       14
# 15                  30                      90                       16
# 16                  32                      92                       18
# 17                  35                      95                       20
#
#     pax_vegan_meal_count  assistance_required_count
# 0                     15                          5
# 1                     10                          4
# 2                     12                          6
# 3                     20                          7
# 4                     18                          9
# 5                     16                         10
# 6                     17                          8
# 7                     14                          5
# 8                     13                          6
# 9                     14                          7
# 10                    16                          4
# 11                    15                          3
# 12                    22                          6
# 13                    19                          7
# 14                    20                          8
# 15                    19                          9
# 16                    22                          6
# 17                    25                          7
